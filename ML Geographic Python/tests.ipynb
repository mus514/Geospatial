# %%
import geopandas as gpd
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats
import matplotlib.ticker as mtick
import rasterio
from rasterio.plot import show

# %%
# Improve quality of the plots
set_matplotlib_formats('svg')
# Set the style of the plot
plt.style.use('seaborn-v0_8-deep')
# Out:
# C:\Users\mustapha.bouhsen\AppData\Local\Temp\ipykernel_13508\2773171772.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
shape_file = gpd.read_file('data/example.shp')
print(shape_file)
# Out:
#            ID                                           geometry
# 0         B02  POLYGON ((1921010.417 1155809.1, 1921045.24 11...
# 1         B03  POLYGON ((1496001.707 835089.555, 1495999.954 ...
# 2  B01_Montrg  POLYGON ((1807975.744 912013.595, 1808507.419 ...

# %%
shape_file.plot()
# Out:
# <Axes: >

# %%
shape_file.geometry[1]
# Out:
# <POLYGON ((1496001.707 835089.555, 1495999.954 835086.935, 1495959.03 835014...>

# %%
img = rasterio.open('data/example.tif')

# %%
show(img)
# Out:
# <Axes: >
